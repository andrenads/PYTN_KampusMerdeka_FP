# %% [markdown]
# <H3 align='center'> Python Final Project 2 : <br> Rain in Australia </H3>

# %% [markdown]
# <div style="text-align:center">
#     <img src="https://east.vc/wp-content/uploads/2020/01/hacktiv8-1.png" alt="Logo Hacktiv8" />
# </div>

# %% [markdown]
# <div style="text-align:center">
#     <u> OLEH : </u><br></br>
#     Kelompok 4
#     <table style="border:none; margin: 0 auto; text-align:left;">
#         <tr>
#             <td style="border: none;">Resti Apriliyanti</td>
#             <td style="border: none;">(PYTN-KS20-011)</td>
#         </tr>
#         <tr>
#             <td style="border: none;">Andrena Dhiffa Salsabila</td>
#             <td style="border: none;">(PYTN-KS20-02)</td>
#         </tr>
#     </table>
#         <br>Program : Python for Data Science
# </div>
# <br></br>

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Introduction
# <p style="text-align: justify; font-size: 14px;">
#     Cuaca adalah faktor penting dalam kehidupan sehari-hari kami dan memiliki dampak yang signifikan pada berbagai aspek. Dengan prediksi cuaca dalam kehidupan sehari-hari akan berdampak pada berbagai keputusan dan aktivitas. Melalui dataset "weatherAUS.csv" yang menyediakan informasi cuaca harian di berbagai lokasi di Australia, termasuk atribut "RainTomorrow" yang menunjukkan apakah akan hujan besok. Kemampuan untuk memprediksi hujan besok memiliki signifikansi dalam banyak konteks, seperti perencanaan luar ruangan, pertanian, dan manajemen sumber daya alam.
# </p>
#
# <p style="text-align: justify; font-size: 14px;">
#     Salah satu pendekatan yang umum digunakan dalam analisis data cuaca adalah regresi logistik (logistic regression), merupakan teknik machine learning yang dapat memodelkan hubungan antara atribut-atribut cuaca dan probabilitas hujan besok. Dengan memahami faktor-faktor yang berkontribusi pada hujan besok, kami dapat meningkatkan pemahaman kami tentang cuaca dan memberikan informasi berharga bagi individu dan organisasi.
# </p>
#
# <p style="text-align: justify; font-size: 14px;">
#     Proyek ini bertujuan untuk menerapkan regresi logistik pada dataset ini, memproses data dengan mengatasi masalah data yang hilang, outlier, dan normalisasi, dan mengukur kinerja model. Hasil dari analisis ini akan memberikan pemahaman yang lebih baik tentang sejauh mana prediksi cuaca dapat digunakan untuk memberikan informasi berharga dalam pengambilan keputusan sehari-hari.
# </p>

# %% [markdown]
# ### Rumusan Masalah
# <p style="text-align: justify; font-size: 14px;">
#     <ol style="text-align: justify; font-size: 14px;">
#         <li>
#             Apakah besok akan hujan atau tidak di Australia jika hari ini hujan?
#     </ol>
# </p>

# %% [markdown]
# ### Dataset
# <div style="text-align:center; font-size:14px">
# <p>
#     Dataset : <a href=https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package>Rain in Australia</a>
# </p>
#     <table style="border:none; margin: 0 auto; text-align:left;">
#         <tr>
#             <td style="text-align:center"><b>No.</b></td>
#             <td style="text-align:center"><b>Variabel</b></td>
#             <td style="text-align:center"><b>Keterangan</b></td>
#         </tr>
#         <tr>
#             <td style="text-align:center">1. </td>
#             <td>Date</td>
#             <td>tanggal hari itu.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">2. </td>
#             <td>Location</td>
#             <td>lokasi, nama kota di Australia.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">3. </td>
#             <td>MinTemp</td>
#             <td>temperatur terendah hari itu dalam celcius.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">4. </td>
#             <td>MaxTemp</td>
#             <td>temperatur tertinggi hari itu dalam celcius.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">5. </td>
#             <td>Rainfall</td>
#             <td>jumlah curah hujan hari itu dalam mm.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">6. </td>
#             <td>Evaporation</td>
#             <td>jumlah evaporasi dalam mm dari Class A pan selama 24 jam sebelum jam 9 pagi hari itu.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">7. </td>
#             <td>Sunshine</td>
#             <td>jumlah jam hari itu cerah dengan cahaya matahari.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">8. </td>
#             <td>WindGustDir</td>
#             <td>arah kecepatan angin yang paling tinggi selama 24 jam sebelum jam 12 malam hari itu.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">9. </td>
#             <td>WindGustSpeed</td>
#             <td>kecepatan angin yang paling tinggi dalam km/jam selama 24 jam sebelum jam 12 malam hari itu.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">10. </td>
#             <td>WindDir9am</td>
#             <td>arah angin jam 9 pagi.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">11. </td>
#             <td>WindDir3pm</td>
#             <td>arah angin jam 3 sore.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">12. </td>
#             <td>WindSpeed9am</td>
#             <td>kecepatan angin jam 9 pagi dalam km/jam dihitung dari rata-rata kecepatan angin 10 menit sebelum jam 3 sore.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">13. </td>
#             <td>WindSpeed3pm</td>
#             <td>kecepatan angin jam 3 sore dalam km/jam dihitung dari rata-rata kecepatan angin 10 menit sebelum jam 3 sore.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">14. </td>
#             <td>Humidity9am</td>
#             <td>humiditas jam 9 pagi dalam persen.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">15. </td>
#             <td>Humidity3pm</td>
#             <td>humiditas jam 3 sore dalam persen.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">16. </td>
#             <td>Pressure9am</td>
#             <td>tekanan udara jam 9 pagi dalam hpa.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">17. </td>
#             <td>Pressure3pm</td>
#             <td>tekanan udara jam 3 sore dalam hpa.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">18. </td>
#             <td>Cloud9am</td>
#             <td>persentase langit yang tertutup awan jam 9 pagi. dihitung dalamoktas, unit ⅛, menghitung berapa unit ⅛ dari langit yang tertutup awan. Jika 0,langit cerah, jika 8, langit sepenuhnya tertutup awan.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">19. </td>
#             <td>Cloud3pm</td>
#             <td>persentase langit yang tertutup awan jam 3 sore.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">20. </td>
#             <td>Temp9am</td>
#             <td>temperatur jam 9 pagi dalam celcius.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">21. </td>
#             <td>Temp3pm</td>
#             <td>temperatur jam 3 sore dalam celcius.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">22. </td>
#             <td>RainToday</td>
#             <td>apakah hari ini hujan: jika curah hujan 24 jam sebelum jam 9 pagi melebihi 1mm, maka nilai ini adalah 1, jika tidak nilai nya 0.</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">23. </td>
#             <td>RainTomorrow</td>
#             <td>variable yang mau di prediksi.</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ## Python Implementation

# %% [markdown]
# ### 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# Visualization
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Modelling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from pickle import dump,load

# Ignore warning
import warnings
warnings.simplefilter(action="ignore")

# %% [markdown]
# ### 2. Data Loading

# %%
df = pd.read_csv('dataset/weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# Mengecek dimensi dataset
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# #### 3.1 Mengecek Tipe Data Variabel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# Berdasarkan data, semua tipe data sudah sesuai sehingga tidak perlu dilakikan konversi tipe data.

# %% [markdown]
# #### 3.2 Mengecek dan Menangani *Missing Value* pada Data

# %%
# Mengecek Nilai Null (missing values)
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#menampilka persentase missing values tiap kolom
miss_value = df.apply(lambda x: f'{((x.isnull().sum()/df.shape[0])*100).round(2)} %')
miss_value
# Out:
# Date               0.0 %
# Location           0.0 %
# MinTemp           1.02 %
# MaxTemp           0.87 %
# Rainfall          2.24 %
# Evaporation      43.17 %
# Sunshine         48.01 %
# WindGustDir        7.1 %
# WindGustSpeed     7.06 %
# WindDir9am        7.26 %
# WindDir3pm        2.91 %
# WindSpeed9am      1.21 %
# WindSpeed3pm      2.11 %
# Humidity9am       1.82 %
# Humidity3pm        3.1 %
# Pressure9am      10.36 %
# Pressure3pm      10.33 %
# Cloud9am         38.42 %
# Cloud3pm         40.81 %
# Temp9am           1.21 %
# Temp3pm           2.48 %
# RainToday         2.24 %
# RainTomorrow      2.25 %
# dtype: object

# %% [markdown]
# Berdasarkan persentase, terdapat 4 kolom yang memiliki banyak *missing values* (> 30%), yaitu 'Cloud3pm', 'Cloud9am', 'Sunshine', dan 'Evaporation'. Ke-4 kolom ini juga tidak mempengaruhi data untuk memprediksi variabel 'RainTomorrow'. Untuk itu, agar tidak mengurangi keakuratan data, ke-4 kolom ini lebih baik dihapus.

# %%
# menghapus 4 kolom yang memiliki <30% missing values
df.drop(columns=["Cloud3pm", "Cloud9am", "Sunshine", "Evaporation"], 
        inplace=True)

# %%
# menghapus kolom yang tidak diperlukan 
df.drop(columns='Date', inplace=True)

# %%
df.shape
# Out:
# (145460, 18)

# %% [markdown]
# ##### 3.2.1 Menangani *Missing Values* pada Kolom Kategori

# %%
# Mengecek jumlah missing values pada kolom kategori
categorical = [var for var in df.columns if df[var].dtype=='O']
df[categorical]
# Out:
#        Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0        Albury           W          W        WNW        No           No
# 1        Albury         WNW        NNW        WSW        No           No
# 2        Albury         WSW          W        WSW        No           No
# 3        Albury          NE         SE          E        No           No
# 4        Albury           W        ENE         NW        No           No
# ...         ...         ...        ...        ...       ...          ...
# 145455    Uluru           E         SE        ENE        No           No
# 145456    Uluru         NNW         SE          N        No           No
# 145457    Uluru           N         SE        WNW        No           No
# 145458    Uluru          SE        SSE          N        No           No
# 145459    Uluru         NaN        ESE        ESE        No          NaN
#
# [145460 rows x 6 columns]

# %%
df[categorical].isnull().sum()
# Out:
# Location            0
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
# Menghapus baris missing values untuk kolom 'RainToday' dan 'RainTomorrow'
df = df.dropna(subset=['RainToday', 'RainTomorrow'], axis = 0)

# %%
# Mengganti nilai missing values dengan modus
df['WindGustDir'].fillna(df['WindGustDir'].mode()[0], inplace=True)
df['WindDir9am'].fillna(df['WindDir9am'].mode()[0], inplace=True)
df['WindDir3pm'].fillna(df['WindDir3pm'].mode()[0], inplace=True)

# %%
# Memastikan nilai missing values pada kolom kategori sudah tidak ada
df[categorical].isnull().sum()
# Out:
# Location        0
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %% [markdown]
# ##### 3.2.1 Menangani *Missing Values* pada Kolom Numerik

# %%
numerical = [var for var in df.columns if df[var].dtype == 'float64']
df[numerical]
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# ...         ...      ...       ...            ...           ...           ...
# 145454      3.5     21.8       0.0           31.0          15.0          13.0
# 145455      2.8     23.4       0.0           31.0          13.0          11.0
# 145456      3.6     25.3       0.0           22.0          13.0           9.0
# 145457      5.4     26.9       0.0           37.0           9.0           9.0
# 145458      7.8     27.0       0.0           28.0          13.0           7.0
#
# ...

# %%
df[numerical].isnull().sum()
# Out:
# MinTemp            468
# MaxTemp            307
# Rainfall             0
# WindGustSpeed     9105
# WindSpeed9am      1055
# WindSpeed3pm      2531
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Temp9am            656
# Temp3pm           2624
# dtype: int64

# %% [markdown]
# Untuk mengganti *missing values* pada setiap kolom perlu dilakukan visualisasi data melalui box plot atau hist plot untuk menentukan data tersebut harus diganti dengan mean atau median.

# %%
for i in numerical:
    fig, axs = plt.subplots(1,2,figsize=(15, 3))

    sns.histplot(df[i],bins=20, kde=True,ax=axs[0])
    sns.boxplot(data = df[i], x = df[i], ax = axs[1], fliersize=1)

# %% [markdown]
# Berdasarkan visualisasi sebaran data, kolom 'Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm' karena terlalu banyak outliers sehingga perlu dilkukan *handling outliers* agar tidak mengacaukan data.

# %%
# Handling outlier menggunakan IQR

# Menghitung Q1, Q3, dan IQR
Q1 = df[['Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm']].quantile(0.25)
Q3 = df[['Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm']].quantile(0.75)
IQR = Q3 - Q1

# Menghitung batas atas (maximum) dan batas bawah (minimum)
maximum = Q3 + 1.5 * IQR
minimum = Q1 - 1.5 * IQR

print('Nilai Maximum : \n', maximum)
print('Nilai Minimum : \n', minimum)
# Out:
# Nilai Maximum :
#  Rainfall          2.0
# WindGustSpeed    73.5
# WindSpeed9am     37.0
# WindSpeed3pm     40.5
# dtype: float64
# Nilai Minimum :
#  Rainfall         -1.2
# WindGustSpeed     5.5
# WindSpeed9am    -11.0
# WindSpeed3pm     -3.5
# dtype: float64

# %%
# Melakukan align pada DataFrames
df, maximum = df.align(maximum, axis=1, join='outer')
df, minimum = df.align(minimum, axis=1, join='outer')

more_than = (df > maximum)
lower_than = (df < minimum)

# Menerapkan mask pada axis=1 (kolom)
df = df.mask(more_than, maximum, axis=1)
df = df.mask(lower_than, minimum, axis=1)

# %%
# Melihat persebaran data setelah dilakukan handling outliers
print(df[['Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm']].describe())
# Out:
#             Rainfall  WindGustSpeed   WindSpeed9am   WindSpeed3pm
# count  140787.000000   131682.00000  139732.000000  138256.000000
# mean        0.485723       39.77675      13.901168      18.543224
# std         0.791851       12.96363       8.586483       8.521464
# min         0.000000        6.00000       0.000000       0.000000
# 25%         0.000000       31.00000       7.000000      13.000000
# 50%         0.000000       39.00000      13.000000      19.000000
# 75%         0.800000       48.00000      19.000000      24.000000
# max         2.000000       73.50000      37.000000      40.500000

# %%
# Membuat box plots untuk memvisualisasikan data setelah handling outlier
plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.boxplot(column='Rainfall')
fig.set_title('')
fig.set_ylabel('Rainfall')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='WindGustSpeed')
fig.set_title('')
fig.set_ylabel('WindGustSpeed')


plt.subplot(2, 2, 3)
fig = df.boxplot(column='WindSpeed9am')
fig.set_title('')
fig.set_ylabel('WindSpeed9am')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='WindSpeed3pm')
fig.set_title('')
fig.set_ylabel('WindSpeed3pmm')
# Out:
# Text(0, 0.5, 'WindSpeed3pmm')

# %%
# Mengganti missing values dengan median
df['MinTemp'].fillna(df['MinTemp'].median(), inplace=True)
df['MaxTemp'].fillna(df['MaxTemp'].median(), inplace=True)
df['WindGustSpeed'].fillna(df['WindGustSpeed'].median(), inplace=True)
df['WindSpeed9am'].fillna(df['WindSpeed9am'].median(), inplace=True)
df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].median(), inplace=True)
df['Humidity9am'].fillna(df['Humidity9am'].median(), inplace=True)
df['Humidity3pm'].fillna(df['Humidity3pm'].median(), inplace=True)
df['Pressure9am'].fillna(df['Pressure9am'].median(), inplace=True)
df['Pressure3pm'].fillna(df['Pressure3pm'].median(), inplace=True)
df['Temp9am'].fillna(df['Temp9am'].median(), inplace=True)
df['Temp3pm'].fillna(df['Temp3pm'].median(), inplace=True)

# %%
df[numerical].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# dtype: int64

# %%
# Memastikan kembali tidak ada lagi missing values pada data
df.isnull().sum()
# Out:
# Humidity3pm      0
# Humidity9am      0
# Location         0
# MaxTemp          0
# MinTemp          0
# Pressure3pm      0
# Pressure9am      0
# RainToday        0
# RainTomorrow     0
# Rainfall         0
# Temp3pm          0
# Temp9am          0
# WindDir3pm       0
# WindDir9am       0
# WindGustDir      0
# WindGustSpeed    0
# WindSpeed3pm     0
# WindSpeed9am     0
# dtype: int64

# %% [markdown]
# #### 3.4 Menghapus Data Duplikat

# %%
# Mengecek jumlah file duplikat
df.duplicated().sum()
# Out:
# 45

# %% [markdown]
# Berdasarkan data, ada 45 data yang merupakan duplikat dari data lainnya sehingga perlu dilakukan penghapusan data.

# %%
# Menghapus data duplikat 
df.drop_duplicates(keep=False, inplace=True)
print('Jumlah data duplikat', df.duplicated().sum())
# Out:
# Jumlah data duplikat 0

# %% [markdown]
# ### 4. Data Exploration

# %% [markdown]
# #### 4.1 Mengekplorasi Nilai Unik Setiap Kolom

# %%
for col in df.columns:
    print("UNIQUE VALUES FOR ",col)
    print("="*20)
    print(df[col].unique())
    print("="*20)
# Out:
# UNIQUE VALUES FOR  Humidity3pm
# ...
# [ 22.  25.  30.  16.  33.  23.  19.   9.  27.  91.  93.  43.  82.  65.
#   32.  26.  28.  24.  17.  15.  70.  12.   8.  31.  20.  10.  21.  39.
#   13.  11.  69.  18.  14.  35.  90.  68.  74.  41.  34.  78.  49.  37.
#   42.  47.  52.  29.  86.  89.  62.  79.  48.  46.  38.  44.  51.  36.
#   45.  40.  53.  61.  59.  63.  54.  57.  50.  58.  75.  97.  80.  95.
#   56.  72.  60.  71.  73.  81.  76.  64.  87.  85.  67.  55.  77.  84.
#    7.  99.  92.  66.  83.  94.  96.  88. 100.  98.   5.   6.   1.   4.
#    2.   3.   0.]
# ...
# UNIQUE VALUES FOR  Humidity9am
# ...
# [ 71.  44.  38.  45.  82.  55.  49.  48.  42.  58.  89.  76.  65.  69.
#   80.  47.  56.  54.  41.  78.  46.  43.  33.  34.  36.  52.  51.  40.
#   35.  39.  60.  37.  27.  32.  53.  20.  66.  50.  63.  57.  62.  87.
#   61.  59.  92.  72.  67.  75.  88.  68.  73.  74.  83.  77.  70.  81.
#   86.  97.  99.  91.  85.  93.  84.  94.  79.  98.  96.  95.  90.  64.
# ...

# %% [markdown]
# #### 4.2 Mendeskripsikan Data Bertipe Kategori

# %%
print("Describe categorical data:")
df.describe(exclude = "number")
# Out:
# Describe categorical data:
#         Location RainToday RainTomorrow WindDir3pm WindDir9am WindGustDir
# count     140733    140733       140733     140733     140733      140733
# unique        49         2            2         16         16          16
# top     Canberra        No           No         SE          N           W
# freq        3402    109280       109534      14194      20872       18805

# %% [markdown]
# #### 4.3 Mendeskripsikan Data Bertipe Numerik

# %%
print("Describe numerical data:")
df.describe().T
# Out:
# Describe numerical data:
#                   count         mean        std    min     25%     50%  \
# Humidity3pm    140733.0    51.462777  20.551086    0.0    37.0    52.0
# Humidity9am    140733.0    68.839029  18.964675    0.0    57.0    70.0
# MaxTemp        140733.0    23.233674   7.108041   -4.8    17.9    22.6
# MinTemp        140733.0    12.184280   6.394460   -8.5     7.6    12.0
# Pressure3pm    140733.0  1015.252314   6.683830  977.1  1011.0  1015.2
# Pressure9am    140733.0  1017.649268   6.750503  980.5  1013.5  1017.6
# Rainfall       140733.0     0.485881   0.791927    0.0     0.0     0.0
# Temp3pm        140733.0    21.682350   6.874604   -5.4    16.7    21.1
# Temp9am        140733.0    16.985838   6.482131   -7.2    12.3    16.7
# WindGustSpeed  140733.0    39.726795  12.541281    6.0    31.0    39.0
# WindSpeed3pm   140733.0    18.551264   8.446352    0.0    13.0    19.0
# WindSpeed9am   140733.0    13.894758   8.556226    0.0     7.0    13.0
#
# ...

# %% [markdown]
# ### 5. Data Visualization

# %% [markdown]
# 5.1 Perbandingan antara besok hujan atau tidak selama 10 tahun

# %%
nrows,ncols = 2,1
fig,ax = plt.subplots(figsize=(14,4),dpi=200,nrows=nrows,ncols=ncols,sharex=True)
for i,j,k in zip(range(nrows),["RainToday","RainTomorrow"],["Rain Today","Rain Tomorrow"]):
    countplot = sns.countplot(data=df,y=j,palette=["#6AAB9C","#E06C78"],order=["Yes","No"],ax=ax[i])
    for l in countplot.containers:
        countplot.bar_label(l,padding=5)
    ax[i].set_xlabel("")
    ax[i].set_xlim(0,115000)
    ax[i].set_ylabel(k)
ax[1].set_xlabel("Frequency")
plt.suptitle("Perbandingan Hujan dan Tidak Hujan", y=1.05, fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan bar chart, diketahui bahwa kolom RainTomorrow (y atau target) tergolong imbalanced dengan nilai 'No' hampir 3x lipat lebih tinggi daripada nilai 'Yes' dari total data.

# %% [markdown]
# 5.2 Persentase perbandingan antara besok hujan atau tidak selama 10 tahun

# %%
colors_list = ['gold', 'yellowgreen']
explode_list = [0, 0.1]

df['RainTomorrow'].value_counts().plot(kind='pie',                            
                            figsize=(9, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         
                            pctdistance=1.12,    
                            colors=colors_list,  
                            explode=explode_list
                            )

plt.title('Persentase antara besok hujan atau tidak selama 10 tahun di Australia', y=1.1) 
plt.xlabel('0: Tidak Hujan, 1: Hujan')
plt.axis('equal') 

# add legend
plt.legend(labels=df['RainTomorrow'].index, loc='upper left') 

plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan bar chart, diketahui bahwa persentase 'RainTomorrow' untuk label "Yes" sebesar 22,2% dan label "No" sebesar 77,8%. Hal ini berarti terdapat ketidakseimbangan label pada sampel dataset, dimana label "No" 3x lebih banyak dibandingkan label "Yes".

# %% [markdown]
# 5.3 Jumlah Turun Hujan Besok Berdasarkan Lokasi

# %%
# Kelompokkan data berdasarkan location untuk label 'Yes'
loc_no = df[
    (df['RainTomorrow']=="Yes")
].groupby('Location').agg({'RainTomorrow':'count'}).sort_values(by='RainTomorrow')
loc_no.plot(kind='barh', figsize=(12,18), color=['Teal'])

plt.ylabel("Location", fontsize=14)
plt.xlabel("Jumlah Kejadian", fontsize=14)
plt.title("Jumlah Terjadinya Hari Besok Hujan Berdasarkan Lokasi di Australia")
plt.legend()
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan chart, diketahui bahwa lima kota dengan data kejadian "Rain Tomorrow" berlabel 'Yes' tertinggi diantaranya adalah Portland, Caims, Walpole, Dartmoor, dan MountGambier. Sehingga dapat disimpulkan bahwa pada lokasi tersebut sering terjadi hujan di hari besoknya.

# %% [markdown]
# 5.4 Jumlah Tidak Turun Hujan Besok Berdasarkan Lokasi

# %%
# Kelompokkan data berdasarkan location untuk label 'No'
loc_no = df[
    (df['RainTomorrow']=="No")
].groupby('Location').agg({'RainTomorrow':'count'}).sort_values(by='RainTomorrow')
loc_no.plot(kind='barh', figsize=(10,18), color=['Tan'])

plt.ylabel("Location", fontsize=14)
plt.xlabel("Jumlah Kejadian", fontsize=14)
plt.title("Jumlah Terjadinya Hari Besok Tidak Hujan Berdasarkan Lokasi di Australia")
plt.legend()
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan chart, diketahui bahwa lima kota dengan data kejadian "Rain Tomorrow" berlabel 'No' tertinggi diantaranya adalah Canberra, Woomera, AliceSprings, Mildura, dan Cobar. Sehingga dapat disimpulkan bahwa pada lokasi tersebut jarang terjadi hujan di hari besoknya.

# %% [markdown]
# ### 6. Data Preprocessing

# %%
df.head()
# Out:
#    Humidity3pm  Humidity9am Location  MaxTemp  MinTemp  Pressure3pm  \
# 0         22.0         71.0   Albury     22.9     13.4       1007.1
# 1         25.0         44.0   Albury     25.1      7.4       1007.8
# 2         30.0         38.0   Albury     25.7     12.9       1008.7
# 3         16.0         45.0   Albury     28.0      9.2       1012.8
# 4         33.0         82.0   Albury     32.3     17.5       1006.0
#
#    Pressure9am RainToday RainTomorrow  Rainfall  Temp3pm  Temp9am WindDir3pm  \
# 0       1007.7        No           No       0.6     21.8     16.9        WNW
# 1       1010.6        No           No       0.0     24.3     17.2        WSW
# 2       1007.6        No           No       0.0     23.2     21.0        WSW
# 3       1017.6        No           No       0.0     26.5     18.1          E
# 4       1010.8        No           No       1.0     29.7     17.8         NW
#
#   WindDir9am WindGustDir  WindGustSpeed  WindSpeed3pm  WindSpeed9am
# ...

# %% [markdown]
# #### 6.1 Encoding Data

# %%
le = LabelEncoder()
df.WindGustDir = le.fit_transform(df.WindGustDir)
df.WindDir9am = le.fit_transform(df.WindDir9am)
df.WindDir3pm = le.fit_transform(df.WindDir3pm)
df.Location = le.fit_transform(df.Location)
df.RainToday = le.fit_transform(df.RainToday)
df.RainTomorrow = le.fit_transform(df.RainTomorrow)

# %%
correlation = df.corr()
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Rain Forecast in Australia')
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan bar chart, diketahui bahwa 'MaxTemp' dan 'Temp3pm' memiliki tingkat korelasi sekitar 0.97. Kemudian 'Rainfall' dan 'RainToday' juga memiliki korelasi 0.97.

# %% [markdown]
# #### 6.2 Spliting Data

# %%
# Memisahkan fitur dan target
X = df.drop('RainTomorrow', axis=1)
Y = df['RainTomorrow']

# %%
# Membagi data menjadi data latih dan data uji
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# #### 6.3 Definisi Model

# %%
# Inisialisasi model

logreg_model = LogisticRegression()
knn_model = KNeighborsClassifier()
svm_model = SVC()
dt_model = DecisionTreeClassifier()
rf_model = RandomForestClassifier()
nb_model = GaussianNB()

# %% [markdown]
# #### 6.4 Evaluasi Model

# %% [markdown]
# a. Logistic Regression

# %%
# Melatih dan mengevaluasi Logistic Regression
logreg_model.fit(scaled_X_train, Y_train)
logreg_pred = logreg_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, logreg_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, logreg_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Logistic Regression")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     22011
#            1       0.71      0.47      0.57      6136
#
#     accuracy                           0.84     28147
#    macro avg       0.79      0.71      0.74     28147
# weighted avg       0.83      0.84      0.83     28147
#
# ...
#
# Model: Logistic Regression
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        20846         1165
# Actual 1         3237         2899

# %% [markdown]
# b. K-Nearest Neighbors (KNN)

# %%
# Melatih dan mengevaluasi K-Nearest Neighbors (KNN)
knn_model.fit(scaled_X_train, Y_train)
knn_pred = knn_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, knn_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, knn_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: K-Nearest Neighbors (KNN)")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - K-Nearest Neighbors (KNN)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90     22011
#            1       0.67      0.49      0.57      6136
#
#     accuracy                           0.84     28147
#    macro avg       0.77      0.71      0.73     28147
# weighted avg       0.82      0.84      0.83     28147
#
# ...
#
# Model: K-Nearest Neighbors (KNN)
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        20497         1514
# Actual 1         3103         3033

# %% [markdown]
# c. Support Vector Machine (SVM)

# %%
# Melatih dan mengevaluasi Support Vector Machine (SVM)
svm_model.fit(scaled_X_train, Y_train)
svm_pred = svm_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, svm_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, svm_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Support Vector Machine (SVM)")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Support Vector Machine (SVM)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     22011
#            1       0.77      0.46      0.58      6136
#
#     accuracy                           0.85     28147
#    macro avg       0.82      0.71      0.74     28147
# weighted avg       0.85      0.85      0.84     28147
#
# ...
#
# Model: Support Vector Machine (SVM)
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        21188          823
# Actual 1         3303         2833

# %% [markdown]
# d. Decision Tree

# %%
# Melatih dan mengevaluasi Decision Tree
dt_model.fit(scaled_X_train, Y_train)
dt_pred = dt_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, dt_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, dt_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Decision Tree")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Decision Tree")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86     22011
#            1       0.50      0.53      0.52      6136
#
#     accuracy                           0.78     28147
#    macro avg       0.68      0.69      0.69     28147
# weighted avg       0.79      0.78      0.79     28147
#
# ...
#
# Model: Decision Tree
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        18788         3223
# Actual 1         2877         3259

# %% [markdown]
# e. Random Forest

# %%
# Melatih dan mengevaluasi Random Forest
rf_model.fit(scaled_X_train, Y_train)
rf_pred = rf_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, rf_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, rf_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Random Forest")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     22011
#            1       0.75      0.51      0.60      6136
#
#     accuracy                           0.86     28147
#    macro avg       0.81      0.73      0.76     28147
# weighted avg       0.85      0.86      0.84     28147
#
# ...
#
# Model: Random Forest
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        20972         1039
# Actual 1         3027         3109

# %% [markdown]
# f. Naive Bayes

# %%
# Melatih dan mengevaluasi Naive Bayes
nb_model.fit(scaled_X_train, Y_train)
nb_pred = nb_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, nb_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, nb_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Naive Bayes")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Naive Bayes")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85     22011
#            1       0.49      0.58      0.53      6136
#
#     accuracy                           0.78     28147
#    macro avg       0.68      0.71      0.69     28147
# weighted avg       0.79      0.78      0.78     28147
#
# ...
#
# Model: Naive Bayes
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0        18287         3724
# Actual 1         2556         3580

# %% [markdown]
# ### Perbandingan Model

# %%
# Inisialisasi model
models = [
    "Logistic Regression",
    "K-Nearest Neighbors (KNN)",
    "Support Vector Machine (SVM)",
    "Decision Tree",
    "Random Forest",
    "Naive Bayes"
]

# Confusion Matrix
confusion_matrices = [
    confusion_matrix(Y_test, logreg_pred),
    confusion_matrix(Y_test, knn_pred),
    confusion_matrix(Y_test, svm_pred),
    confusion_matrix(Y_test, dt_pred),
    confusion_matrix(Y_test, rf_pred),
    confusion_matrix(Y_test, nb_pred)
]

# Classification Report
classification_reports = [
    classification_report(Y_test, logreg_pred, output_dict=True),
    classification_report(Y_test, knn_pred, output_dict=True),
    classification_report(Y_test, svm_pred, output_dict=True),
    classification_report(Y_test, dt_pred, output_dict=True),
    classification_report(Y_test, rf_pred, output_dict=True),
    classification_report(Y_test, nb_pred, output_dict=True)
]

# Membuat DataFrame
df_results = pd.DataFrame({
    'Model': models,
    'Confusion Matrix': confusion_matrices,
    'Classification Report': classification_reports
})

# Memisahkan metrik-metrik evaluasi
df_results['Precision (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['precision'])
df_results['Precision (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['precision'])
df_results['Recall (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['recall'])
df_results['Recall (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['recall'])
df_results['F1-score (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['f1-score'])
df_results['F1-score (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['f1-score'])

# Menghapus kolom 'Classification Report' yang tidak diperlukan
df_results.drop('Classification Report', axis=1, inplace=True)

# Menampilkan DataFrame
df_results
# Out:
#                           Model               Confusion Matrix  Precision (0)  \
# 0           Logistic Regression  [[20846, 1165], [3237, 2899]]       0.865590
# 1     K-Nearest Neighbors (KNN)  [[20497, 1514], [3103, 3033]]       0.868517
# 2  Support Vector Machine (SVM)   [[21188, 823], [3303, 2833]]       0.865134
# 3                 Decision Tree  [[18788, 3223], [2877, 3259]]       0.867205
# 4                 Random Forest  [[20972, 1039], [3027, 3109]]       0.873870
# 5                   Naive Bayes  [[18287, 3724], [2556, 3580]]       0.877369
#
#    Precision (1)  Recall (0)  Recall (1)  F1-score (0)  F1-score (1)
# 0       0.713337    0.947072    0.472458      0.904500      0.568431
# 1       0.667033    0.931216    0.494296      0.898774      0.567818
# 2       0.774891    0.962610    0.461701      0.911273      0.578636
# 3       0.502777    0.853573    0.531128      0.860335      0.516564
# 4       0.749518    0.952796    0.506682      0.911628      0.604629
# ...

# %% [markdown]
# ### Model Inferential

# %%
# save model for future use
model = [logreg_model,svm_model]
file_name = ["logistic_regression_model","support_vector_machine_model"]
extension = "json"

for i,j in zip(model,file_name):
    with open(f"{j}.{extension}","wb") as files:
        dump(i,files)
    print(f"{j}.{extension} has been downloaded")
# Out:
# logistic_regression_model.json has been downloaded
# support_vector_machine_model.json has been downloaded

# %%
logreg_model.fit(X_train, Y_train)
y_pred_log = logreg_model.predict(X_test)

# %%
svm_model.fit(X_train, Y_train)
y_pred_svm = svm_model.predict(X_test)

# %%
scaler_ = StandardScaler()
scaler_.fit(X_train, Y_train)
# Out:
# StandardScaler()

# %%
Location = input("Lokasi : ")
MinTemp = float(input("Suhu Minimal : "))
MaxTemp = float(input("Suhu Maksimal : "))
Rainfall = float(input("Curah Hujan : "))
Evaporation = float(input("Evaporasi :"))
Sunshine = float(input("Hari ini Cerah :"))
WindGustDir = float(input("Arah Kecepatan Angin :"))
WindGustSpeed = float(input("Kecepatan Angin : "))
WindDir9am = float(input("Arah Kecepatan Angin Pukul 9 am :"))
WindDir3pm = float(input("Arah Kecepatan Angin Pukul 3 am :"))
WindSpeed9am = float(input("Kecepatan Angin Pukul 9 am : "))
WindSpeed3pm = float(input("Kecepatan Angin Pukul 3 pm : "))
Humidity9am = float(input("Kelembapan Pukul 9 am : "))
Humidity3pm = float(input("Kelembapan Pukul 3 pm : "))
Pressure9am = float(input("Tekanan Udara Pukul 9 am :"))
Pressure3pm = float(input("Tekanan Udara Pukul 3 pm :"))
RainToday = input("Hari ini Hujan? (Yes/No) : ")

val = [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am,
       WindDir3pm,WindSpeed9am,WindSpeed3pm, Humidity9am, Humidity3pm,Pressure9am,Pressure3pm,RainToday ]
val = scaler_.transform([val])
val = val.reshape(17,)

print(val)

val_predict = logreg_model.predict([val])


if val_predict == 1:
    print("Berdasarkan prediksi menggunakan Logistic regression, Maka Besok tidak hujan")
elif val_predict == 0:
    print("Berdasarkan prediksi menggunakan Logistic regression, Maka Besok hujan")
else:
    print("Prediksi tidak valid")
# Out:
# [  -2.4541081    -3.57573708   -1.59703601   -3.12557898   -1.74723056
#  -151.62256769 -150.56850206    1.86198533    0.64784254   -3.00445356
#    -2.46463253   -1.49048897   -1.32822998   -1.50210683   -3.08857025
#    -2.07655351   -1.50656762]
# Berdasarkan prediksi menggunakan Logistic regression, Maka Besok tidak hujan

# %%
Location = input("Lokasi : ")
MinTemp = float(input("Suhu Minimal : "))
MaxTemp = float(input("Suhu Maksimal : "))
Rainfall = float(input("Curah Hujan : "))
Evaporation = float(input("Evaporasi :"))
Sunshine = float(input("Hari ini Cerah :"))
WindGustDir = float(input("Arah Kecepatan Angin :"))
WindGustSpeed = float(input("Kecepatan Angin : "))
WindDir9am = float(input("Arah Kecepatan Angin Pukul 9 am :"))
WindDir3pm = float(input("Arah Kecepatan Angin Pukul 3 am :"))
WindSpeed9am = float(input("Kecepatan Angin Pukul 9 am : "))
WindSpeed3pm = float(input("Kecepatan Angin Pukul 3 pm : "))
Humidity9am = float(input("Kelembapan Pukul 9 am : "))
Humidity3pm = float(input("Kelembapan Pukul 3 pm : "))
Pressure9am = float(input("Tekanan Udara Pukul 9 am :"))
Pressure3pm = float(input("Tekanan Udara Pukul 3 pm :"))
RainToday = input("Hari ini Hujan? (Yes/No) : ")

val = [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am,
       WindDir3pm,WindSpeed9am,WindSpeed3pm, Humidity9am, Humidity3pm,Pressure9am,Pressure3pm,RainToday ]
val = scaler_.transform([val])
val = val.reshape(17,)

print(val)

val_predict = svm_model.predict([val])


if val_predict == 1:
    print("Berdasarkan prediksi menggunakan SVM, Maka Besok tidak hujan")
elif val_predict == 0:
    print("Berdasarkan prediksi menggunakan SVM, Maka Besok hujan")
else:
    print("Prediksi tidak valid")
# Out:
# [  -2.4541081    -3.57573708   -1.59703601   -3.12557898   -1.74723056
#  -151.62256769 -150.56850206    1.86198533    0.64784254   -3.00445356
#    -2.46463253   -1.49048897   -1.32822998   -1.50210683   -3.08857025
#    -2.07655351   -1.50656762]
# Berdasarkan prediksi menggunakan SVM, Maka Besok tidak hujan

# %% [markdown]
# <b> Insight : </b> Berdasarkan data, dapat ditarik kesimpulan berupa :
#
# 1. Logistic Regression: Confusion Matrix menunjukkan model memiliki performa yang baik dalam mengidentifikasi kelas 0 (Tidak Hujan) dengan tingkat presisi dan recall yang tinggi. Namun, untuk kelas 1 (Hujan), model memiliki presisi yang rendah, menunjukkan bahwa ketika model memprediksi hujan, itu tidak selalu akurat.
# 2. K-Nearest Neighbors (KNN): Performa KNN serupa dengan Logistic Regression, dengan tingkat presisi dan recall yang tinggi untuk kelas 0, tetapi presisi yang lebih rendah untuk kelas 1.
# 3. Support Vector Machine (SVM): SVM menunjukkan presisi yang tinggi untuk kedua kelas, namun, recall untuk kelas 1 (Hujan) relatif rendah.
# 4. Decision Tree: Decision Tree memiliki presisi yang baik untuk kelas 0, namun, presisi rendah untuk kelas 1. Recall untuk kedua kelas cukup seimbang.
# 5. Random Forest: Random Forest menunjukkan kinerja yang baik dengan tingkat presisi dan recall yang tinggi untuk kedua kelas.
# 6. Naive Bayes: Naive Bayes memiliki presisi yang baik untuk kelas 0, tetapi presisi yang rendah untuk kelas 1. Recall untuk kelas 1 cukup tinggi, menunjukkan model cenderung mengidentifikasi sebagian besar kasus hujan.
#
# Kesimpulan Umum:
# <li>'MaxTemp' dan 'Temp3pm' memiliki tingkat korelasi sekitar 0.97. Kemudian 'Rainfall' dan 'RainToday' juga memiliki korelasi 0.97.
# <li>Model Random Forest menonjol sebagai model yang memiliki performa baik secara keseluruhan, dengan tingkat presisi dan recall yang tinggi untuk kedua kelas.
# <li>Kelemahan umum pada beberapa model adalah presisi yang rendah untuk memprediksi hujan (kelas 1).
# <li>Performa model dapat disempurnakan melalui penyesuaian parameter atau penggunaan teknik pengolahan data yang lebih lanjut.
# <li>Evaluasi lebih lanjut, seperti analisis ROC-AUC, dapat memberikan wawasan tambahan tentang performa model.
